# %%
import pandas as pd
import streamlit as st 
from streamlit_folium import st_folium
import folium
#openpyxl
# Out:
# 2025-06-04 23:23:34.159 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
lien = "dataset_annonce_train.xlsx"
df = pd.read_excel(lien)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_annonce               1800 non-null   object
#  1   titre_annonce            1800 non-null   object
#  2   date_mise_en_ligne       1800 non-null   object
#  3   statut                   1800 non-null   object
#  4   date_suppression         1232 non-null   object
#  5   prix                     1800 non-null   int64
#  6   surface_m2               1800 non-null   int64
#  7   surface_terrain_m2       420 non-null    float64
#  8   charges_mensuelles       1747 non-null   float64
#  9   taxe_fonciere            1710 non-null   float64
#  10  type_bien                1800 non-null   object
#  11  nb_chambres              1800 non-null   int64
#  12  etage                    1335 non-null   float64
#  13  ascenseur                1250 non-null   float64
# ...

# %%
df.describe().T
# Out:
#                          count           mean            std          min  \
# prix                    1800.0  416318.293333  327868.091224  44102.00000
# surface_m2              1800.0      84.083333      55.692904     18.00000
# surface_terrain_m2       420.0     779.433333     385.822035    151.00000
# charges_mensuelles      1747.0     102.257012      79.268266      0.00000
# taxe_fonciere           1710.0     621.125146     491.510062     66.00000
# nb_chambres             1800.0       2.083889       1.487082      0.00000
# etage                   1335.0       2.972285       1.980788      0.00000
# ascenseur               1250.0       0.619200       0.485778      0.00000
# annee_construction      1800.0    1996.183889      15.885361   1970.00000
# balcon                  1800.0       0.211667       0.408603      0.00000
# terrasse                1800.0       0.245000       0.430207      0.00000
# jardin                  1800.0       0.300000       0.458385      0.00000
# ...

# %%
import folium

m = folium.Map (location=[-1.48333, 43.48333], zoom_start=16)
folium. Marker([-1.48333, 43.48333], popup="Bayonne",
tooltip="Bayonne"
).add_to (m)
# call to render Folium map in Streamlit
st_data = st_folium(m, width= 725)
# Out:
# 2025-06-04 23:18:58.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 23:18:58.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 23:18:58.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-04 23:18:58.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
